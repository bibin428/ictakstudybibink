# %%
import pandas as pd
data = pd.read_csv("/content/train_loan.csv")
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isnull().mean()
data.isnull().mean() *100
round(data.isnull().mean() *100,2)
# Out:
# Loan_ID              0.00
# Gender               2.12
# Married              0.49
# Dependents           2.44
# Education            0.00
# Self_Employed        5.21
# ApplicantIncome      0.00
# CoapplicantIncome    0.00
# LoanAmount           3.58
# Loan_Amount_Term     2.28
# Credit_History       8.14
# Property_Area        0.00
# Loan_Status          0.00
# dtype: float64

# %%
data=data.dropna(subset=["Married"])
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               0
# Dependents           12
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           21
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
round(data.isnull().mean() *100,2)
# Out:
# Loan_ID              0.00
# Gender               2.13
# Married              0.00
# Dependents           1.96
# Education            0.00
# Self_Employed        5.24
# ApplicantIncome      0.00
# CoapplicantIncome    0.00
# LoanAmount           3.44
# Loan_Amount_Term     2.29
# Credit_History       8.18
# Property_Area        0.00
# Loan_Status          0.00
# dtype: float64

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       611.000000         611.000000  590.000000        597.000000
# mean       5399.513912        1627.972046  146.369492        341.909548
# std        6120.764249        2931.747971   85.729343         64.900325
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2875.500000           0.000000  100.000000        360.000000
# 50%        3800.000000        1213.000000  127.500000        360.000000
# 75%        5790.000000        2304.000000  168.000000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      561.000000
# mean         0.841355
# std          0.365671
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
import seaborn as sns
sns.boxplot(data["LoanAmount"])
# Out:
# <Axes: ylabel='LoanAmount'>

# %%
sns.boxplot(data["Loan_Amount_Term"])
# Out:
# <Axes: ylabel='Loan_Amount_Term'>

# %%
sns.boxplot(data["Credit_History"])
# Out:
# <Axes: ylabel='Credit_History'>

# %%
print(data["LoanAmount"].median())
print(data["Loan_Amount_Term"].median())
print(data["Credit_History"].median())
# Out:
# 127.5
# 360.0
# 1.0

# %%
data["LoanAmount"].fillna(127.5,inplace=True)
data["Loan_Amount_Term"].fillna(360,inplace=True)
data["Credit_History"].fillna(1,inplace=True)
# Out:
# /tmp/ipython-input-351278092.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["LoanAmount"].fillna(127.5,inplace=True)
# /tmp/ipython-input-351278092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["LoanAmount"].fillna(127.5,inplace=True)
# ...

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               0
# Dependents           12
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
print(data["Gender"].mode())
print(data["Dependents"].mode())
print(data["Self_Employed"].mode())
# Out:
# 0    Male
# Name: Gender, dtype: object
# 0    0
# Name: Dependents, dtype: object
# 0    No
# Name: Self_Employed, dtype: object

# %%
data["Gender"].fillna("Male",inplace=True)
data["Dependents"].fillna("0",inplace=True)
data["Self_Employed"].fillna("No",inplace=True)
# Out:
# /tmp/ipython-input-1729130521.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Gender"].fillna("Male",inplace=True)
# /tmp/ipython-input-1729130521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Gender"].fillna("Male",inplace=True)
# ...

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       611.000000         611.000000  611.000000        611.000000
# mean       5399.513912        1627.972046  145.720949        342.324059
# std        6120.764249        2931.747971   84.310975         64.208419
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2875.500000           0.000000  100.000000        360.000000
# 50%        3800.000000        1213.000000  127.500000        360.000000
# 75%        5790.000000        2304.000000  165.000000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      611.000000
# mean         0.854337
# std          0.353057
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
sns.boxplot(data )
# Out:
# <Axes: >

# %%
data.select_dtypes("number").skew().sort_values(ascending=False)
# Out:
# CoapplicantIncome    7.479901
# ApplicantIncome      6.535346
# LoanAmount           2.737750
# Credit_History      -2.013844
# Loan_Amount_Term    -2.444382
# dtype: float64

# %%
column=data.select_dtypes(include='number').columns
column
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
import pandas as pd
def remove_outliers(data, column):
  data_filtered=data

  for i in column:
    Q1=data[i].quantile(0.25)
    Q3=data[i].quantile(0.75)
    IQR=Q3-Q1

    lower_whisker=Q1-1.5*IQR
    upper_whisker=Q3+1.5*IQR

    data_filtered=data_filtered[(data_filtered[i]>=lower_whisker) & (data_filtered[i]<=upper_whisker)]

  return data_filtered

# %%
data=remove_outliers(data,column)

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
data.select_dtypes("number").skew().sort_values(ascending=False)
# Out:
# ApplicantIncome      1.127771
# CoapplicantIncome    0.822475
# LoanAmount           0.485968
# Loan_Amount_Term     0.000000
# Credit_History       0.000000
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

catcolumns = ['Gender', 'Married', 'Education', 'Self_Employed', 'Loan_Status']
le = LabelEncoder()

# Apply the encoder to each column
for col in catcolumns:
    data[col] = le.fit_transform(data[col])

# %%
data = pd.get_dummies(data, columns=['Property_Area'])

onehotcol = ['Property_Area_Rural', 'Property_Area_Semiurban', 'Property_Area_Urban']

for col in onehotcol:
    data[col] = data[col].astype(int)

# %%
data['Dependents'] = data['Dependents'].replace(to_replace='3+', value='3')
data['Dependents'] = data['Dependents'].astype(int)

# %%
data
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        0           0          0              0
# 1    LP001003       1        1           1          0              0
# 2    LP001005       1        1           0          0              1
# 3    LP001006       1        1           0          1              0
# 4    LP001008       1        0           0          0              0
# ..        ...     ...      ...         ...        ...            ...
# 607  LP002964       1        1           2          1              0
# 608  LP002974       1        1           0          0              0
# 609  LP002978       0        0           0          0              0
# 611  LP002983       1        1           1          0              0
# 612  LP002984       1        1           2          0              0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
X = data.drop(columns=['Loan_Status', 'Loan_ID'], axis=1)
y = data['Loan_Status']

# %%
from sklearn.preprocessing import StandardScaler


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 0.48810297, -1.3421693 , -0.69770673, ..., -0.67246255,
#         -0.80363756,  1.54145009],
#        [ 0.48810297,  0.74506249,  0.34227122, ...,  1.48707166,
#         -0.80363756, -0.64873979],
#        [ 0.48810297,  0.74506249, -0.69770673, ..., -0.67246255,
#         -0.80363756,  1.54145009],
#        ...,
#        [-2.04874801, -1.3421693 , -0.69770673, ...,  1.48707166,
#         -0.80363756, -0.64873979],
#        [ 0.48810297,  0.74506249,  0.34227122, ..., -0.67246255,
#         -0.80363756,  1.54145009],
#        [ 0.48810297,  0.74506249,  1.38224918, ..., -0.67246255,
#         -0.80363756,  1.54145009]])
